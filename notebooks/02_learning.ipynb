# %% [markdown]
# # 02 — Dictionary learning: the emergent-filter grid
#
# **Stage 3.** Run the owned dictionary-learning loop on whitened patches (~2×
# overcomplete) and produce the grid of learned basis functions.
#
# **Deliverable:** localized, oriented, bandpass filters emerging from an efficient-coding
# objective alone.
#
# > **This is a reproduction of Olshausen & Field (1996), not a contribution of this repo.**
# > The contribution is downstream: notebooks 03 and 04.
#
# **Gate:** `pytest tests/test_inference.py` must pass before this notebook runs on real
# patches.
#
# _Scaffold only. Nothing implemented yet._
