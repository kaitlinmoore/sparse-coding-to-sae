# %% [markdown]
# # 03 — Tuning analysis vs. macaque V1
#
# **Stage 4 (contribution).** Fit a 2D Gabor to every learned dictionary element; extract
# orientation, spatial frequency, phase, and envelope widths (nx, ny).
#
# **Deliverable:** tuning distributions, and the headline figure — the nx–ny envelope
# scatter overlaid on Ringach (2002) macaque V1 simple-cell values.
#
# **Honesty requirements (CLAUDE.md):** report the well-fit fraction; do not silently drop
# poorly-fit elements from the distributions; report the known sparse-coding-vs-real-V1
# discrepancy (learned fields skew blobbier and more symmetric than real V1) rather than
# tuning it away.
#
# _Scaffold only. Nothing implemented yet._
