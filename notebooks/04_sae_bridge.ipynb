# %% [markdown]
# # 04 — The SAE bridge: amortized vs. iterative inference
#
# **Stage 5 (contribution).** Train the small sparse autoencoder (linear encoder → ReLU →
# linear decoder, L1 on codes) on the same whitened patches the iterative solver saw.
#
# **The sharp question:** does an amortized feed-forward encoder recover the same
# receptive-field statistics as Olshausen & Field's iterative per-example inference — or
# does amortization change the learned dictionary?
#
# **Deliverable:** SAE dictionary vs. Stage 3 dictionary, compared by (a) Gabor-parameter
# distributions and (b) greedy cosine matching.
#
# _Scaffold only. Nothing implemented yet._
